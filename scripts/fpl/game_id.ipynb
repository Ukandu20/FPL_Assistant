# %%
import requests
import pandas as pd
from pathlib import Path
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json

pd.set_option("display.max_columns", None)

# %%
fb = pd.read_csv("../../data/processed/fbref/ENG-Premier League/2024-2025/player_match/misc.csv")

gws = pd.read_csv("../../data/processed/fpl/2024-25/gws/merged_gws.csv")


teams = pd.read_csv("../../data/raw/fpl/2024-25/teams.csv", usecols=["id", "name"])

with open("../../data/processed/_id_lookup_teams.json", "r", encoding="utf-8") as f:
    team_map = json.load(f)
with open("../../data/config/teams.json", "r", encoding="utf-8") as f:
    short_code = json.load(f)

team_map_norm = {k.strip().lower(): v.strip().upper() for k, v in team_map.items()}
short_code_norm = {k.strip().lower(): v.strip().upper() for k, v in short_code.items()}

# %%
teams["team"] = teams["name"].str.strip().str.lower().map(short_code_norm)
teams["team_id"] = teams["name"].str.strip().str.lower().map(team_map_norm).str.lower()
teams["opponent_id"] = teams["id"]

#assign the opponents team_id based on the opponent id such that if the opponent_id = 16, the opponent_team_id for that row is the team_id for the team with id=16
id_to_hex = teams.set_index("id")["team_id"].to_dict()   # '39ae6c81' → 'MUN'

#teams = teams.drop(columns="id")

gws = gws[gws["player_id"].notna()]


gws["opponent_id"] = gws["opponent_team"].map(id_to_hex)

code_lookup  = teams.set_index("team_id")["team"]

gws["opponent_team"] = gws["opponent_id"].map(code_lookup)


team_id = teams[["team_id", "opponent_id"]]

# %%
team_lookup = teams[["team_id", "team"]]

# 2) merge DataFrame ↔ DataFrame
gws_merged = gws.merge(
    team_lookup,
    on=["team"],      # both columns exist in *both* frames
    how="left"                   # or "inner", as you need
)

display(gws_merged)
# Out:
#        round first_name                second_name                name team  \
# 0          1       alex                      scott          alex scott  BOU
# 1          1     carlos  miguel dos santos pereira       carlos miguel  NFO
# 2          1   tomiyasu                   takehiro   takehiro tomiyasu  ARS
# 3          1    malcolm                    ebiowei     malcolm ebiowei  CRY
# 4          1        ben              brereton díaz        ben brereton  SOU
# ...      ...        ...                        ...                 ...  ...
# 26372      9      myles               lewis-skelly  myles lewis-skelly  ARS
# 26373      9    giovani                   lo celso    giovani lo celso  TOT
# 26374      9    tawanda                    chirewa     tawanda chirewa  WOL
# 26375      9     ashley                      young        ashley young  EVE
# 26376      9      james                       bree          james bree  SOU
#
#       position player_id fpl_pos   xP  assists  bonus  bps  clean_sheets  \
# 0          MID  6140a758     MID  1.6        0      0   11             0
# 1           GK  634e99a6      GK  2.2        0      0    0             0
# 2          DEF  38b63d6c     DEF  0.0        0      0    0             0
# 3          MID  c1d71cd0     MID  0.0        0      0    0             0
# 4          FWD  00e1d69d     FWD  1.0        0      0   -2             0
# ...        ...       ...     ...  ...      ...    ...  ...           ...
# 26372      DEF  e78bcfe3     DEF  0.3        0      0    5             0
# 26373      MID  004432dc     MID  0.0        0      0    0             0
# 26374      MID  09350915     MID  0.0        0      0    0             0
# 26375      DEF  ba08791f     DEF  6.0        1      1   23             0
# 26376      DEF  6242a194     DEF -1.3        0      0    4             0
#
#        creativity  element  expected_assists  expected_goal_involvements  \
# 0            12.8       77              0.01                        0.01
# 1             0.0      427              0.00                        0.00
# 2             0.0       22              0.00                        0.00
# 3             0.0      197              0.00                        0.00
# 4            14.0      584              0.02                        0.32
# ...           ...      ...               ...                         ...
# 26372         0.4      597              0.00                        0.00
# 26373         0.0      493              0.00                        0.00
# 26374         0.0      538              0.00                        0.00
# 26375        12.3      238              0.50                        0.50
# 26376        10.7      457              0.02                        0.02
#
#        expected_goals  expected_goals_conceded  fixture  goals_conceded  \
# 0                 0.0                     1.02        6               1
# 1                 0.0                     0.00        6               0
# 2                 0.0                     0.00        2               0
# 3                 0.0                     0.00        8               0
# 4                 0.3                     0.25        5               1
# ...               ...                      ...      ...             ...
# 26372             0.0                     0.31       81               1
# 26373             0.0                     0.00       86               0
# 26374             0.0                     0.00       84               0
# 26375             0.0                     1.26       87               1
# 26376             0.0                     0.56       89               0
#
#        goals_scored  ict_index  influence          kickoff_time  minutes  \
# 0                 0        3.6       22.8  2024-08-17T14:00:00Z       62
# 1                 0        0.0        0.0  2024-08-17T14:00:00Z        0
# 2                 0        0.0        0.0  2024-08-17T14:00:00Z        0
# 3                 0        0.0        0.0  2024-08-18T13:00:00Z        0
# 4                 0        3.3        2.6  2024-08-17T14:00:00Z       70
# ...             ...        ...        ...                   ...      ...
# 26372             0        0.6        3.2  2024-10-27T16:30:00Z       14
# 26373             0        0.0        0.0  2024-10-27T14:00:00Z        0
# 26374             0        0.0        0.0  2024-10-26T14:00:00Z        0
# 26375             0        4.7       32.4  2024-10-26T16:30:00Z       90
# 26376             0        1.4        3.6  2024-10-26T14:00:00Z       13
#
#        modified opponent_team  own_goals  penalties_missed  penalties_saved  \
# 0         False           NFO          0                 0                0
# 1         False           BOU          0                 0                0
# 2         False           WOL          0                 0                0
# 3         False           BRE          0                 0                0
# 4         False           NEW          0                 0                0
# ...         ...           ...        ...               ...              ...
# 26372     False           LIV          0                 0                0
# 26373     False           CRY          0                 0                0
# 26374     False           BHA          0                 0                0
# 26375     False           FUL          0                 0                0
# 26376     False           MCI          0                 0                0
#
#        red_cards  saves  selected  starts  team_a_score  team_h_score  threat  \
# 0              0      0      4339       1             1             1     0.0
# 1              0      0     33324       0             1             1     0.0
# 2              0      0      8462       0             0             2     0.0
# 3              0      0       716       0             1             2     0.0
# 4              0      0     66244       1             0             1    16.0
# ...          ...    ...       ...     ...           ...           ...     ...
# 26372          0      0      6485       0             2             2     2.0
# 26373          0      0      3592       0             0             1     0.0
# 26374          0      0      3939       0             2             2     0.0
# 26375          0      0     66981       1             1             1     2.0
# 26376          0      0     16402       0             0             1     0.0
#
#        total_points  transfers_balance  transfers_in  transfers_out  value  \
# 0                 2                  0             0              0     50
# 1                 0                  0             0              0     45
# 2                 0                  0             0              0     50
# 3                 0                  0             0              0     45
# 4                 1                  0             0              0     55
# ...             ...                ...           ...            ...    ...
# 26372             1                -62           254            316     45
# 26373             0               -118             0            118     49
# 26374             0               -187             0            187     45
# 26375             6              17991         23660           5669     45
# 26376             1               -271           155            426     40
#
#        was_home  yellow_cards  mng_clean_sheets  mng_draw  mng_goals_scored  \
# 0         False             0               NaN       NaN               NaN
# 1          True             0               NaN       NaN               NaN
# 2          True             0               NaN       NaN               NaN
# 3         False             0               NaN       NaN               NaN
# 4         False             1               NaN       NaN               NaN
# ...         ...           ...               ...       ...               ...
# 26372      True             0               NaN       NaN               NaN
# 26373     False             0               NaN       NaN               NaN
# 26374     False             0               NaN       NaN               NaN
# 26375      True             0               NaN       NaN               NaN
# 26376     False             0               NaN       NaN               NaN
#
#        mng_loss  mng_underdog_draw  mng_underdog_win  mng_win opponent_id  \
# 0           NaN                NaN               NaN      NaN    ef41d35d
# 1           NaN                NaN               NaN      NaN    2fdd3467
# 2           NaN                NaN               NaN      NaN    42ab0080
# 3           NaN                NaN               NaN      NaN    71af9b33
# 4           NaN                NaN               NaN      NaN    8a5a1622
# ...         ...                ...               ...      ...         ...
# 26372       NaN                NaN               NaN      NaN    84d4105e
# 26373       NaN                NaN               NaN      NaN    8ace9f04
# 26374       NaN                NaN               NaN      NaN    80396060
# 26375       NaN                NaN               NaN      NaN    1aff263c
# 26376       NaN                NaN               NaN      NaN    dbbe5abf
#
#         team_id
# 0      2fdd3467
# 1      ef41d35d
# 2      11cea905
# 3      8ace9f04
# 4      aaa42142
# ...         ...
# 26372  11cea905
# 26373  17ac6a5f
# 26374  42ab0080
# 26375  426079a6
# 26376  aaa42142
#
# [26377 rows x 54 columns]

# %%
lookup = (
    teams[['team', 'team_id']]          # 'team' is short code (ARS, AVL)
         .drop_duplicates(subset='team')
         .set_index('team')['team_id']  # Series: index = 'ARS', value = '39ae6c81'
)
display(gws_merged)
# Out:
#        round first_name                second_name                name team  \
# 0          1       alex                      scott          alex scott  BOU
# 1          1     carlos  miguel dos santos pereira       carlos miguel  NFO
# 2          1   tomiyasu                   takehiro   takehiro tomiyasu  ARS
# 3          1    malcolm                    ebiowei     malcolm ebiowei  CRY
# 4          1        ben              brereton díaz        ben brereton  SOU
# ...      ...        ...                        ...                 ...  ...
# 26372      9      myles               lewis-skelly  myles lewis-skelly  ARS
# 26373      9    giovani                   lo celso    giovani lo celso  TOT
# 26374      9    tawanda                    chirewa     tawanda chirewa  WOL
# 26375      9     ashley                      young        ashley young  EVE
# 26376      9      james                       bree          james bree  SOU
#
#       position player_id fpl_pos   xP  assists  bonus  bps  clean_sheets  \
# 0          MID  6140a758     MID  1.6        0      0   11             0
# 1           GK  634e99a6      GK  2.2        0      0    0             0
# 2          DEF  38b63d6c     DEF  0.0        0      0    0             0
# 3          MID  c1d71cd0     MID  0.0        0      0    0             0
# 4          FWD  00e1d69d     FWD  1.0        0      0   -2             0
# ...        ...       ...     ...  ...      ...    ...  ...           ...
# 26372      DEF  e78bcfe3     DEF  0.3        0      0    5             0
# 26373      MID  004432dc     MID  0.0        0      0    0             0
# 26374      MID  09350915     MID  0.0        0      0    0             0
# 26375      DEF  ba08791f     DEF  6.0        1      1   23             0
# 26376      DEF  6242a194     DEF -1.3        0      0    4             0
#
#        creativity  element  expected_assists  expected_goal_involvements  \
# 0            12.8       77              0.01                        0.01
# 1             0.0      427              0.00                        0.00
# 2             0.0       22              0.00                        0.00
# 3             0.0      197              0.00                        0.00
# 4            14.0      584              0.02                        0.32
# ...           ...      ...               ...                         ...
# 26372         0.4      597              0.00                        0.00
# 26373         0.0      493              0.00                        0.00
# 26374         0.0      538              0.00                        0.00
# 26375        12.3      238              0.50                        0.50
# 26376        10.7      457              0.02                        0.02
#
#        expected_goals  expected_goals_conceded  fixture  goals_conceded  \
# 0                 0.0                     1.02        6               1
# 1                 0.0                     0.00        6               0
# 2                 0.0                     0.00        2               0
# 3                 0.0                     0.00        8               0
# 4                 0.3                     0.25        5               1
# ...               ...                      ...      ...             ...
# 26372             0.0                     0.31       81               1
# 26373             0.0                     0.00       86               0
# 26374             0.0                     0.00       84               0
# 26375             0.0                     1.26       87               1
# 26376             0.0                     0.56       89               0
#
#        goals_scored  ict_index  influence          kickoff_time  minutes  \
# 0                 0        3.6       22.8  2024-08-17T14:00:00Z       62
# 1                 0        0.0        0.0  2024-08-17T14:00:00Z        0
# 2                 0        0.0        0.0  2024-08-17T14:00:00Z        0
# 3                 0        0.0        0.0  2024-08-18T13:00:00Z        0
# 4                 0        3.3        2.6  2024-08-17T14:00:00Z       70
# ...             ...        ...        ...                   ...      ...
# 26372             0        0.6        3.2  2024-10-27T16:30:00Z       14
# 26373             0        0.0        0.0  2024-10-27T14:00:00Z        0
# 26374             0        0.0        0.0  2024-10-26T14:00:00Z        0
# 26375             0        4.7       32.4  2024-10-26T16:30:00Z       90
# 26376             0        1.4        3.6  2024-10-26T14:00:00Z       13
#
#        modified opponent_team  own_goals  penalties_missed  penalties_saved  \
# 0         False           NFO          0                 0                0
# 1         False           BOU          0                 0                0
# 2         False           WOL          0                 0                0
# 3         False           BRE          0                 0                0
# 4         False           NEW          0                 0                0
# ...         ...           ...        ...               ...              ...
# 26372     False           LIV          0                 0                0
# 26373     False           CRY          0                 0                0
# 26374     False           BHA          0                 0                0
# 26375     False           FUL          0                 0                0
# 26376     False           MCI          0                 0                0
#
#        red_cards  saves  selected  starts  team_a_score  team_h_score  threat  \
# 0              0      0      4339       1             1             1     0.0
# 1              0      0     33324       0             1             1     0.0
# 2              0      0      8462       0             0             2     0.0
# 3              0      0       716       0             1             2     0.0
# 4              0      0     66244       1             0             1    16.0
# ...          ...    ...       ...     ...           ...           ...     ...
# 26372          0      0      6485       0             2             2     2.0
# 26373          0      0      3592       0             0             1     0.0
# 26374          0      0      3939       0             2             2     0.0
# 26375          0      0     66981       1             1             1     2.0
# 26376          0      0     16402       0             0             1     0.0
#
#        total_points  transfers_balance  transfers_in  transfers_out  value  \
# 0                 2                  0             0              0     50
# 1                 0                  0             0              0     45
# 2                 0                  0             0              0     50
# 3                 0                  0             0              0     45
# 4                 1                  0             0              0     55
# ...             ...                ...           ...            ...    ...
# 26372             1                -62           254            316     45
# 26373             0               -118             0            118     49
# 26374             0               -187             0            187     45
# 26375             6              17991         23660           5669     45
# 26376             1               -271           155            426     40
#
#        was_home  yellow_cards  mng_clean_sheets  mng_draw  mng_goals_scored  \
# 0         False             0               NaN       NaN               NaN
# 1          True             0               NaN       NaN               NaN
# 2          True             0               NaN       NaN               NaN
# 3         False             0               NaN       NaN               NaN
# 4         False             1               NaN       NaN               NaN
# ...         ...           ...               ...       ...               ...
# 26372      True             0               NaN       NaN               NaN
# 26373     False             0               NaN       NaN               NaN
# 26374     False             0               NaN       NaN               NaN
# 26375      True             0               NaN       NaN               NaN
# 26376     False             0               NaN       NaN               NaN
#
#        mng_loss  mng_underdog_draw  mng_underdog_win  mng_win opponent_id  \
# 0           NaN                NaN               NaN      NaN    ef41d35d
# 1           NaN                NaN               NaN      NaN    2fdd3467
# 2           NaN                NaN               NaN      NaN    42ab0080
# 3           NaN                NaN               NaN      NaN    71af9b33
# 4           NaN                NaN               NaN      NaN    8a5a1622
# ...         ...                ...               ...      ...         ...
# 26372       NaN                NaN               NaN      NaN    84d4105e
# 26373       NaN                NaN               NaN      NaN    8ace9f04
# 26374       NaN                NaN               NaN      NaN    80396060
# 26375       NaN                NaN               NaN      NaN    1aff263c
# 26376       NaN                NaN               NaN      NaN    dbbe5abf
#
#         team_id
# 0      2fdd3467
# 1      ef41d35d
# 2      11cea905
# 3      8ace9f04
# 4      aaa42142
# ...         ...
# 26372  11cea905
# 26373  17ac6a5f
# 26374  42ab0080
# 26375  426079a6
# 26376  aaa42142
#
# [26377 rows x 54 columns]

# %%
gws_merged = gws_merged[gws_merged["team_id"].notna()]
na_rows = gws_merged[gws_merged["team_id"].isna()]   # all rows with a NaN

print(gws_merged.columns)
# Out:
# Index(['round', 'first_name', 'second_name', 'name', 'team', 'position',
#        'player_id', 'fpl_pos', 'xP', 'assists', 'bonus', 'bps', 'clean_sheets',
#        'creativity', 'element', 'expected_assists',
#        'expected_goal_involvements', 'expected_goals',
#        'expected_goals_conceded', 'fixture', 'goals_conceded', 'goals_scored',
#        'ict_index', 'influence', 'kickoff_time', 'minutes', 'modified',
#        'opponent_team', 'own_goals', 'penalties_missed', 'penalties_saved',
#        'red_cards', 'saves', 'selected', 'starts', 'team_a_score',
#        'team_h_score', 'threat', 'total_points', 'transfers_balance',
#        'transfers_in', 'transfers_out', 'value', 'was_home', 'yellow_cards',
#        'mng_clean_sheets', 'mng_draw', 'mng_goals_scored', 'mng_loss',
#        'mng_underdog_draw', 'mng_underdog_win', 'mng_win', 'opponent_id',
#        'team_id'],
#       dtype='object')

# %%
na_rows = gws_merged[gws_merged["team_id"].isna()]   # all rows with a NaN

# %%
gws["game_date"] = pd.to_datetime(gws["kickoff_time"]).dt.date.astype(str)
gws["time"] = pd.to_datetime(gws["kickoff_time"]).dt.time.astype(str)

gws = gws.drop(columns=["mng_clean_sheets", "mng_draw", "mng_goals_scored", "mng_loss", "mng_underdog_draw", "mng_underdog_win", "mng_win"])
display(gws)
# Out:
#        round first_name                second_name                name team  \
# 0          1       alex                      scott          alex scott  BOU
# 1          1     carlos  miguel dos santos pereira       carlos miguel  NFO
# 2          1   tomiyasu                   takehiro   takehiro tomiyasu  ARS
# 3          1    malcolm                    ebiowei     malcolm ebiowei  CRY
# 4          1        ben              brereton díaz        ben brereton  SOU
# ...      ...        ...                        ...                 ...  ...
# 27599      9      myles               lewis-skelly  myles lewis-skelly  ARS
# 27600      9    giovani                   lo celso    giovani lo celso  TOT
# 27601      9    tawanda                    chirewa     tawanda chirewa  WOL
# 27603      9     ashley                      young        ashley young  EVE
# 27604      9      james                       bree          james bree  SOU
#
#       position player_id fpl_pos   xP  assists  bonus  bps  clean_sheets  \
# 0          MID  6140a758     MID  1.6        0      0   11             0
# 1           GK  634e99a6      GK  2.2        0      0    0             0
# 2          DEF  38b63d6c     DEF  0.0        0      0    0             0
# 3          MID  c1d71cd0     MID  0.0        0      0    0             0
# 4          FWD  00e1d69d     FWD  1.0        0      0   -2             0
# ...        ...       ...     ...  ...      ...    ...  ...           ...
# 27599      DEF  e78bcfe3     DEF  0.3        0      0    5             0
# 27600      MID  004432dc     MID  0.0        0      0    0             0
# 27601      MID  09350915     MID  0.0        0      0    0             0
# 27603      DEF  ba08791f     DEF  6.0        1      1   23             0
# 27604      DEF  6242a194     DEF -1.3        0      0    4             0
#
#        creativity  element  expected_assists  expected_goal_involvements  \
# 0            12.8       77              0.01                        0.01
# 1             0.0      427              0.00                        0.00
# 2             0.0       22              0.00                        0.00
# 3             0.0      197              0.00                        0.00
# 4            14.0      584              0.02                        0.32
# ...           ...      ...               ...                         ...
# 27599         0.4      597              0.00                        0.00
# 27600         0.0      493              0.00                        0.00
# 27601         0.0      538              0.00                        0.00
# 27603        12.3      238              0.50                        0.50
# 27604        10.7      457              0.02                        0.02
#
#        expected_goals  expected_goals_conceded  fixture  goals_conceded  \
# 0                 0.0                     1.02        6               1
# 1                 0.0                     0.00        6               0
# 2                 0.0                     0.00        2               0
# 3                 0.0                     0.00        8               0
# 4                 0.3                     0.25        5               1
# ...               ...                      ...      ...             ...
# 27599             0.0                     0.31       81               1
# 27600             0.0                     0.00       86               0
# 27601             0.0                     0.00       84               0
# 27603             0.0                     1.26       87               1
# 27604             0.0                     0.56       89               0
#
#        goals_scored  ict_index  influence          kickoff_time  minutes  \
# 0                 0        3.6       22.8  2024-08-17T14:00:00Z       62
# 1                 0        0.0        0.0  2024-08-17T14:00:00Z        0
# 2                 0        0.0        0.0  2024-08-17T14:00:00Z        0
# 3                 0        0.0        0.0  2024-08-18T13:00:00Z        0
# 4                 0        3.3        2.6  2024-08-17T14:00:00Z       70
# ...             ...        ...        ...                   ...      ...
# 27599             0        0.6        3.2  2024-10-27T16:30:00Z       14
# 27600             0        0.0        0.0  2024-10-27T14:00:00Z        0
# 27601             0        0.0        0.0  2024-10-26T14:00:00Z        0
# 27603             0        4.7       32.4  2024-10-26T16:30:00Z       90
# 27604             0        1.4        3.6  2024-10-26T14:00:00Z       13
#
#        modified opponent_team  own_goals  penalties_missed  penalties_saved  \
# 0         False           NFO          0                 0                0
# 1         False           BOU          0                 0                0
# 2         False           WOL          0                 0                0
# 3         False           BRE          0                 0                0
# 4         False           NEW          0                 0                0
# ...         ...           ...        ...               ...              ...
# 27599     False           LIV          0                 0                0
# 27600     False           CRY          0                 0                0
# 27601     False           BHA          0                 0                0
# 27603     False           FUL          0                 0                0
# 27604     False           MCI          0                 0                0
#
#        red_cards  saves  selected  starts  team_a_score  team_h_score  threat  \
# 0              0      0      4339       1             1             1     0.0
# 1              0      0     33324       0             1             1     0.0
# 2              0      0      8462       0             0             2     0.0
# 3              0      0       716       0             1             2     0.0
# 4              0      0     66244       1             0             1    16.0
# ...          ...    ...       ...     ...           ...           ...     ...
# 27599          0      0      6485       0             2             2     2.0
# 27600          0      0      3592       0             0             1     0.0
# 27601          0      0      3939       0             2             2     0.0
# 27603          0      0     66981       1             1             1     2.0
# 27604          0      0     16402       0             0             1     0.0
#
#        total_points  transfers_balance  transfers_in  transfers_out  value  \
# 0                 2                  0             0              0     50
# 1                 0                  0             0              0     45
# 2                 0                  0             0              0     50
# 3                 0                  0             0              0     45
# 4                 1                  0             0              0     55
# ...             ...                ...           ...            ...    ...
# 27599             1                -62           254            316     45
# 27600             0               -118             0            118     49
# 27601             0               -187             0            187     45
# 27603             6              17991         23660           5669     45
# 27604             1               -271           155            426     40
#
#        was_home  yellow_cards opponent_id   game_date      time
# 0         False             0    ef41d35d  2024-08-17  14:00:00
# 1          True             0    2fdd3467  2024-08-17  14:00:00
# 2          True             0    42ab0080  2024-08-17  14:00:00
# 3         False             0    71af9b33  2024-08-18  13:00:00
# 4         False             1    8a5a1622  2024-08-17  14:00:00
# ...         ...           ...         ...         ...       ...
# 27599      True             0    84d4105e  2024-10-27  16:30:00
# 27600     False             0    8ace9f04  2024-10-27  14:00:00
# 27601     False             0    80396060  2024-10-26  14:00:00
# 27603      True             0    1aff263c  2024-10-26  16:30:00
# 27604     False             0    dbbe5abf  2024-10-26  14:00:00
#
# [26377 rows x 48 columns]

# %%
# Home = the row where was_home == True
home_rows = gws[gws["was_home"]]
fixture_df = (
    home_rows
      .rename(columns={"team":"home","opponent_team":"away"})
      .loc[:,["game_date","round","home","away"]]
      .drop_duplicates()
)

# %%
bridge = (
    fixture_df
      .merge(fb,
             left_on=["home","away"],
             right_on=["is_home","is_away"],
             how="left")
      .loc[:,["game_id","home","away"]]
)

missing = bridge[bridge["game_id"].isna()]

display(bridge)
# Out:
#         game_id home away
# 0      4efc72e4  NFO  BOU
# 1      4efc72e4  NFO  BOU
# 2      4efc72e4  NFO  BOU
# 3      4efc72e4  NFO  BOU
# 4      4efc72e4  NFO  BOU
# ...         ...  ...  ...
# 21788  5e8445c1  BRE  LIV
# 21789  5e8445c1  BRE  LIV
# 21790  5e8445c1  BRE  LIV
# 21791  5e8445c1  BRE  LIV
# 21792  5e8445c1  BRE  LIV
#
# [21793 rows x 3 columns]
