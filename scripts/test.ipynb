# %%
import pandas as pd
url = "https://fbref.com/en/comps/9/2022-2023/stats/2022-2023-Premier-League-Stats"

df = pd.read_html(url)

# %%
len(df)
# Out:
# 2

# %%
df[1]
# Out:
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Squad               # Pl                Age
# 0           vs Arsenal                 26               26.7
# 1       vs Aston Villa                 26               26.5
# 2       vs Bournemouth                 31               26.6
# 3         vs Brentford                 25               26.6
# 4          vs Brighton                 29               26.5
# 5           vs Chelsea                 32               26.6
# 6    vs Crystal Palace                 26               26.6
# 7           vs Everton                 28               26.5
# 8            vs Fulham                 29               26.7
# 9      vs Leeds United                 29               26.7
# 10   vs Leicester City                 28               26.6
# 11        vs Liverpool                 28               26.6
# 12  vs Manchester City                 24               26.6
# ...
