# %%
import pandas as pd
from pathlib import Path
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)

# %%
pl_players = pd.read_csv("../data/processed/fbref/ENG-Premier League/2024-2025/player_match/summary.csv")
player_seasons = pd.read_csv("../data/processed/fbref/ENG-Premier League/2024-2025/player_season/defense.csv")

match_df = pd.DataFrame(pl_players)
season_df = pd.DataFrame(player_seasons)

# %%
df = match_df.copy()

# Peek at dtypes & non-numeric offenders
display(df.dtypes.sort_values())
non_num = df.columns.difference(df.select_dtypes(include=[np.number]).columns)
print("Non-numeric columns:", list(non_num)[:20])

# Replace infs, drop exact-constant columns (incl. all-NaN)
df = df.replace([np.inf, -np.inf], np.nan)
const_cols = df.columns[df.nunique(dropna=True) <= 1]
df = df.drop(columns=const_cols)
df = df.drop(columns=[ "jersey_number", "age", "is_promoted"])
print(f"Dropped constant cols: {list(const_cols)}")
# Out:
# is_relegated       int64
# gca                int64
# sca                int64
# prgp               int64
# carries            int64
# blocks             int64
# int                int64
# tkl                int64
# touches            int64
# crdr               int64
# crdy               int64
# sot                int64
# cmp                int64
# sh                 int64
# pk                 int64
# ast                int64
# gls                int64
# min                int64
# prgc               int64
# att_att            int64
# succ               int64
# jersey_number      int64
# is_promoted        int64
# is_home            int64
# is_away            int64
# season             int64
# pkatt              int64
# att                int64
# cmp_cmp          float64
# npxg             float64
# xg               float64
# age              float64
# xag              float64
# fpl_pos           object
# position          object
# opponent_id       object
# game              object
# team              object
# player            object
# team_id           object
# away              object
# home              object
# game_date         object
# game_id           object
# nation            object
# pos               object
# player_id         object
# league            object
# dtype: object
# Non-numeric columns: ['away', 'fpl_pos', 'game', 'game_date', 'game_id', 'home', 'league', 'nation', 'opponent_id', 'player', 'player_id', 'pos', 'position', 'team', 'team_id']
# Dropped constant cols: ['league', 'season']

# %%
# Treat bools as ints and join with numerics
num = pd.concat(
    [
        df.select_dtypes(include=[np.number]).astype('float64'),
        df.select_dtypes(include=['bool']).astype('int8')
    ],
    axis=1
)

# Drop constants again after cast
num = num.loc[:, num.nunique(dropna=True) > 1]

# Spearman handles monotonic but non-linear relationships
corr_s = num.corr(method='spearman', min_periods=25)  # tweak min_periods if needed
corr_s
# Out:
#                    min       gls       ast        pk     pkatt        sh  \
# min           1.000000  0.065657  0.067141  0.023990  0.024802  0.165047
# gls           0.065657  1.000000  0.065963  0.246134  0.227578  0.381122
# ast           0.067141  0.065963  1.000000  0.018558  0.021836  0.138515
# pk            0.023990  0.246134  0.018558  1.000000  0.909955  0.063304
# pkatt         0.024802  0.227578  0.021836  0.909955  1.000000  0.067346
# sh            0.165047  0.381122  0.138515  0.063304  0.067346  1.000000
# sot           0.108870  0.564800  0.098943  0.030971  0.030714  0.646540
# crdy          0.089002 -0.010625  0.002109 -0.008819 -0.010435  0.011391
# crdr         -0.039959  0.002439 -0.007372 -0.004973 -0.005465 -0.012962
# touches       0.779990  0.001941  0.077394 -0.008215 -0.009463  0.156869
# npxg          0.275806  0.219895  0.014275 -0.014275     -0.100891
# xag           0.293791  0.244646  0.022391 -0.022391     -0.089589
# sca           0.422001  0.370452  0.046080 -0.046080     -0.104778
# gca           0.190883  0.168787  0.015355 -0.015355     -0.071940
# cmp           0.094619  0.124648  0.024643 -0.024643     -0.063305
# att           0.104950  0.134141  0.023538 -0.023538     -0.061793
# cmp_cmp      -0.098293 -0.056531  0.021307 -0.021307     -0.025249
# prgp          0.276699  0.246722  0.043166 -0.043166     -0.100147
# carries       0.221122  0.216734  0.023230 -0.023230     -0.072831
# prgc          0.494608  0.414921  0.026350 -0.026350     -0.062830
# att_att       1.000000  0.760834  0.000429 -0.000429     -0.025610
# succ          0.760834  1.000000  0.009085 -0.009085     -0.024824
# is_home       0.000429  0.009085  1.000000 -1.000000     -0.001401
# is_away      -0.000429 -0.009085 -1.000000  1.000000      0.001401
# is_relegated -0.025610 -0.024824 -0.001401  0.001401      1.000000

# %%
def high_corr_pairs(C: pd.DataFrame, thr=0.95):
    a = C.abs()
    tri = a.where(np.triu(np.ones(a.shape), k=1).astype(bool))
    pairs = (tri.stack()
                 .reset_index()
                 .rename(columns={'level_0':'feat_1','level_1':'feat_2',0:'|rho|'})
                 .query('`|rho|` >= @thr')
                 .sort_values('|rho|', ascending=False)
                 .reset_index(drop=True))
    return pairs

high_pairs = high_corr_pairs(corr_s, thr=0.92)  # 0.9–0.95 is typical
display(high_pairs.head(30))
# Out:
#     feat_1   feat_2     |rho|
# 0  is_home  is_away  1.000000
# 1       xg     npxg  0.991044
# 2      cmp      att  0.984572
# 3  touches      att  0.982712
# 4  touches      cmp  0.965824
# 5      att  carries  0.935657
# 6  touches  carries  0.934044
# 7      cmp  carries  0.928357

# %%
target_col = "min"   # <- CHANGE THIS
assert target_col in df.columns

# Build a simple feature matrix: numerics (+ booleans already handled)
X = num.loc[:, num.columns != target_col].copy()
y = df[target_col]

# Drop rows where y is NaN
keep = y.notna()
X, y = X.loc[keep], y.loc[keep]

# Spearman corr with target
with_target = (
    X.apply(lambda s: s.corr(y, method='spearman', min_periods=25))
     .dropna()
     .to_frame('rho_spearman')
     .assign(abs_rho=lambda d: d['rho_spearman'].abs())
     .sort_values('abs_rho', ascending=False)
)
display(with_target.head(40))
# Out:
#               rho_spearman   abs_rho
# touches           0.779990  0.779990
# att               0.753900  0.753900
# carries           0.721684  0.721684
# cmp               0.720678  0.720678
# prgp              0.386764  0.386764
# tkl               0.304000  0.304000
# blocks            0.296478  0.296478
# int               0.291649  0.291649
# sca               0.269773  0.269773
# prgc              0.196508  0.196508
# sh                0.165047  0.165047
# xag               0.156132  0.156132
# att_att           0.150295  0.150295
# succ              0.145365  0.145365
# npxg              0.133173  0.133173
# xg                0.132839  0.132839
# sot               0.108870  0.108870
# gca               0.100341  0.100341
# crdy              0.089002  0.089002
# ast               0.067141  0.067141
# gls               0.065657  0.065657
# cmp_cmp           0.050081  0.050081
# crdr             -0.039959  0.039959
# is_relegated     -0.028331  0.028331
# pkatt             0.024802  0.024802
# pk                0.023990  0.023990
# is_home           0.000163  0.000163
# is_away          -0.000163  0.000163

# %%
fixtures = pd.read_csv("../data/processed/registry/fixtures/2025-2026/fixture_calendar.csv")
fixtures_df = pd.DataFrame(fixtures)

print(fixtures_df.dtypes.sort_values())
# Out:
# fpl_id                    int64
# sched_missing             int64
# is_promoted               int64
# is_home                   int64
# days_since_last_game      int64
# is_relegated              int64
# gw_played                 int64
# gw_orig                   int64
# poss                    float64
# xg                      float64
# xga                     float64
# ga                      float64
# gf                      float64
# date_sched               object
# result                   object
# venue                    object
# status                   object
# date_played              object
# away_id                  object
# home_id                  object
# home                     object
# opponent_id              object
# team_id                  object
# team                     object
# fbref_id                 object
# away                     object
# dtype: object

# %%
import pandas as pd

# Load
df = pd.read_csv("../data/processed/registry/fixtures/2025-2026/player_fixture_calendar.csv")

# 1) Show current dtypes (as you had)
print(df.dtypes.sort_values())

# 2) Check for time components hiding in date columns
date_cols = [c for c in df.columns if c.startswith("date_")]
print("\nDate-like columns:", date_cols)

def time_component_mask(s: pd.Series) -> pd.Series:
    """True where parsed datetime has a non-midnight time component."""
    p = pd.to_datetime(s, errors="coerce")           # parse (NaT for bad/missing)
    return p.notna() & (p.dt.normalize() != p)       # normalize() == floor to 00:00:00

any_issues = False
for c in date_cols:
    m = time_component_mask(df[c])
    n = int(m.sum())
    if n > 0:
        any_issues = True
        print(f"\n⚠️  {c}: {n} rows include a time component (examples):")
        cols_to_show = [x for x in ["player_id","fbref_id","fpl_id"] if x in df.columns]
        print(df.loc[m, [c] + cols_to_show].head(20).to_string(index=False))

if not any_issues:
    print("\n✅ No time components detected — all date_* are date-only (or NaT).")

# 3) (Optional) hard assertion to fail CI if any time sneaks in
for c in date_cols:
    m = time_component_mask(df[c])
    assert not m.any(), f"{c} has {int(m.sum())} rows with time components."
# Out:
# own_goals            int64
# sot                  int64
# gls                  int64
# red_crd              int64
# ast                  int64
# pkatt                int64
# pk_scored            int64
# pk_won               int64
# is_starter           int64
# is_active            int64
# days_since_last      int64
# minutes              int64
# blocks               int64
# shots                int64
# tkl                  int64
# fdr_away             int64
# fdr_home             int64
# was_home             int64
# clr                  int64
# recoveries           int64
# yellow_crd           int64
# gw_played            int64
# gw_orig              int64
# fpl_id               int64
# int                  int64
# saves              float64
# sot_against        float64
# save_pct           float64
# xag                float64
# bonus              float64
# ga                 float64
# gf                 float64
# clean_sheets       float64
# bps                float64
# total_points       float64
# xp                 float64
# price              float64
# npxg               float64
# date_sched          object
# date_played         object
# team_id             object
# opponent_id         object
# player              object
# venue               object
# player_id           object
# pos                 object
# starter_source      object
# team                object
# fbref_id            object
# dtype: object
#
# Date-like columns: ['date_sched', 'date_played']
#
# ✅ No time components detected — all date_* are date-only (or NaT).
